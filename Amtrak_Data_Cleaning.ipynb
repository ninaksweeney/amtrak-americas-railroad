# %% [markdown]
# # The Opportunity Within Amtrak - Data Cleaning Notebook

# %% [markdown]
# This project focuses on drilling down to a focused audience for Amtrak to target with climate-focused messaging. In order to find such a specific audience, data from multiple sources needs to be collected, cleaned, and joined together. This notebook handles climate opinion, census, and college data prior to mapping a final recommendation.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Climate Opinion Data

# %% [markdown]
# This data from a Yale study on national Climate Opinions gives scores by metro area (CBSA) for certain questions about climate change. The dataset includes the percentage of people who answered yes and no to each question.

# %%
opinions = pd.read_csv('Yale_Climate_Opinions.csv')
#only take the opinions by metro area, not state or other geography
cbsa_opinions = opinions[opinions.GeoType=="CBSA"]
pd.options.display.max_columns=100

# %%
#we are only going to focus on a few relevant questions, dropping everything else
cbsa_opinions.drop(labels=['affectweatherOppose', 'affectweather', 'harmplantsOppose', 
                          'harmplants', 'devharmOppose','devharm','harmUSOppose', 'harmUS',
                          'personalOppose', 'personal', 'teachGWOppose', 'teachGW', 'gwvoteimpOppose',
                          'gwvoteimp', 'mediaweeklyOppose', 'mediaweekly','rebatesOppose','rebates',
                          'drillANWROppose', 'drillANWR', 'drilloffshoreOppose', 'drilloffshore', 'CO2limitsOppose',
                          'CO2limits', 'corporationsOppose','corporations', 'presidentOppose','president',
                          'congressOppose','congress', 'governorOppose','governor','localofficialsOppose',
                          'localofficials', 'reducetaxOppose','reducetax', 'timingOppose',
                          'timing', 'futuregenOppose','futuregen', 'consensusOppose', 'consensus',
                          'priorityOppose', 'priority', 'fundrenewables', 'fundrenewablesOppose',
                          'supportRPS', 'supportRPSOppose'], axis=1, inplace=True)

# %%
cbsa_opinions.head(3)
# Out:
#      GeoType  GEOID       GeoName  TotalPop  discuss  discussOppose  citizens  \
# 3630    CBSA  10100  Aberdeen, SD     32537   32.062         67.913    59.163
# 3631    CBSA  10140  Aberdeen, WA     57009   36.515         63.218    61.745
# 3632    CBSA  10180   Abilene, TX    129610   29.539         70.491    56.557
#
#       citizensOppose  regulate  regulateOppose  happening  happeningOppose  \
# 3630          12.432    70.796          28.165     66.159           15.979
# 3631          11.793    71.429          27.738     69.182           14.057
# 3632          15.176    66.797          33.178     60.471           18.649
#
#        human  humanOppose  worried  worriedOppose
# 3630  51.649       37.041   56.314         43.735
# 3631  53.290       34.998   58.796         41.183
# 3632  49.543       38.356   54.973         45.151

# %%
#the following are the national averages for each question according to the 
#Yale study website
discuss_average= 35
regulate_average = 75
citizens_average = 64
happening_average = 72
human_average = 57
worried_average = 63

av_list = [discuss_average, regulate_average, citizens_average, happening_average, human_average,worried_average]
col_list = ['discuss', 'regulate', 'citizens', 'happening', 'human', 'worried']

# %%
#measure each metro area's distance (positive or negative) from the 
#national average on each question
def distance_from_nat_average(row, nat_average):
    difference = row-nat_average 
    return difference

for av, col in zip(av_list, col_list):
    cbsa_opinions[f'{col}_distance_from_natav'] = cbsa_opinions.apply(lambda x: distance_from_nat_average(x[col], av), axis=1)

# %%
cbsa_opinions.head(3)
# Out:
#      GeoType  GEOID       GeoName  TotalPop  discuss  discussOppose  citizens  \
# 3630    CBSA  10100  Aberdeen, SD     32537   32.062         67.913    59.163
# 3631    CBSA  10140  Aberdeen, WA     57009   36.515         63.218    61.745
# 3632    CBSA  10180   Abilene, TX    129610   29.539         70.491    56.557
#
#       citizensOppose  regulate  regulateOppose  happening  happeningOppose  \
# 3630          12.432    70.796          28.165     66.159           15.979
# 3631          11.793    71.429          27.738     69.182           14.057
# 3632          15.176    66.797          33.178     60.471           18.649
#
#        human  humanOppose  worried  worriedOppose  \
# 3630  51.649       37.041   56.314         43.735
# 3631  53.290       34.998   58.796         41.183
# 3632  49.543       38.356   54.973         45.151
#
#       discuss_distance_from_natav  regulate_distance_from_natav  \
# 3630                       -2.938                        -4.204
# 3631                        1.515                        -3.571
# 3632                       -5.461                        -8.203
#
#       citizens_distance_from_natav  happening_distance_from_natav  \
# 3630                        -4.837                         -5.841
# 3631                        -2.255                         -2.818
# 3632                        -7.443                        -11.529
#
#       human_distance_from_natav  worried_distance_from_natav
# 3630                     -5.351                       -6.686
# 3631                     -3.710                       -4.204
# 3632                     -7.457                       -8.027

# %%
cbsa_opinions.drop(labels=['discussOppose', 'citizensOppose', 'regulateOppose', 'happeningOppose', 'humanOppose',
                          'worriedOppose'], axis=1, inplace=True)
cbsa_opinions.reset_index(inplace=True)

# %%
#sum up all of the distances from the national average to get an 
#overall sense of how that metro area compares to the rest of the country 
#on climate
cbsa_opinions['sum_of_distances'] = cbsa_opinions['worried_distance_from_natav'] + cbsa_opinions['happening_distance_from_natav']+cbsa_opinions['citizens_distance_from_natav']

# %%
#save the cleaned data
cbsa_opinions.to_csv('Cleaned_Climate_Opinions.csv')

# %% [markdown]
# ## Census Data

# %% [markdown]
# Age could also be an interesting factor to take into account when choosing a target audience. Below we clean census data for each metro area which summarizes the age statistics for the area.

# %%
census_age = pd.read_csv('Census_Age_Data.csv')
census_age.head(3)
# Out:
#            GEO_ID                     NAME                     S0101_C01_001E  \
# 0              id     Geographic Area Name  Estimate!!Total!!Total population
# 1  310M500US10140  Aberdeen, WA Micro Area                              75061
# 2  310M500US10180   Abilene, TX Metro Area                             171795
#
#                              S0101_C01_001M  \
# 0  Margin of Error!!Total!!Total population
# 1                                     *****
# 2                                      2878
#
#                                       S0101_C01_002E  \
# 0  Estimate!!Total!!Total population!!AGE!!Under ...
# 1                                               3852
# 2                                              11570
#
#                                       S0101_C01_002M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                669
# 2                                                484
#
#                                       S0101_C01_003E  \
# 0  Estimate!!Total!!Total population!!AGE!!5 to 9...
# 1                                               3260
# 2                                               9896
#
#                                       S0101_C01_003M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                838
# 2                                               1458
#
#                                       S0101_C01_004E  \
# 0  Estimate!!Total!!Total population!!AGE!!10 to ...
# 1                                               5005
# 2                                              12450
#
#                                       S0101_C01_004M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                765
# 2                                               1361
#
#                                       S0101_C01_005E  \
# 0  Estimate!!Total!!Total population!!AGE!!15 to ...
# 1                                               4828
# 2                                              13195
#
#                                       S0101_C01_005M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                687
# 2                                               1456
#
#                                       S0101_C01_006E  \
# 0  Estimate!!Total!!Total population!!AGE!!20 to ...
# 1                                               3184
# 2                                              15460
#
#                                       S0101_C01_006M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                629
# 2                                               1469
#
#                                       S0101_C01_007E  \
# 0  Estimate!!Total!!Total population!!AGE!!25 to ...
# 1                                               4062
# 2                                              12915
#
#                                       S0101_C01_007M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                406
# 2                                               1181
#
#                                       S0101_C01_008E  \
# 0  Estimate!!Total!!Total population!!AGE!!30 to ...
# 1                                               4529
# 2                                              11620
#
#                                       S0101_C01_008M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                699
# 2                                                709
#
#                                       S0101_C01_009E  \
# 0  Estimate!!Total!!Total population!!AGE!!35 to ...
# 1                                               3376
# 2                                              11087
#
#                                       S0101_C01_009M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                776
# 2                                               1706
#
#                                       S0101_C01_010E  \
# 0  Estimate!!Total!!Total population!!AGE!!40 to ...
# 1                                               4792
# 2                                              11579
#
#                                       S0101_C01_010M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                885
# 2                                               1883
#
#                                       S0101_C01_011E  \
# 0  Estimate!!Total!!Total population!!AGE!!45 to ...
# 1                                               4867
# 2                                               7663
#
#                                       S0101_C01_011M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                577
# 2                                                895
#
#                                       S0101_C01_012E  \
# 0  Estimate!!Total!!Total population!!AGE!!50 to ...
# 1                                               4862
# 2                                               8459
#
#                                       S0101_C01_012M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                591
# 2                                                910
#
#                                       S0101_C01_013E  \
# 0  Estimate!!Total!!Total population!!AGE!!55 to ...
# 1                                               5830
# 2                                              10242
#
#                                       S0101_C01_013M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                               1058
# 2                                               1277
#
#                                       S0101_C01_014E  \
# 0  Estimate!!Total!!Total population!!AGE!!60 to ...
# 1                                               5754
# 2                                               9308
#
#                                       S0101_C01_014M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                               1084
# 2                                               1089
#
#                                       S0101_C01_015E  \
# 0  Estimate!!Total!!Total population!!AGE!!65 to ...
# 1                                               4959
# 2                                               9118
#
#                                       S0101_C01_015M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                969
# 2                                               1266
#
#                                       S0101_C01_016E  \
# 0  Estimate!!Total!!Total population!!AGE!!70 to ...
# 1                                               5643
# 2                                               5563
#
#                                       S0101_C01_016M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                               1003
# 2                                               1086
#
#                                       S0101_C01_017E  \
# 0  Estimate!!Total!!Total population!!AGE!!75 to ...
# 1                                               2950
# 2                                               4935
#
#                                       S0101_C01_017M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                553
# 2                                                817
#
#                                       S0101_C01_018E  \
# 0  Estimate!!Total!!Total population!!AGE!!80 to ...
# 1                                               1917
# 2                                               2930
#
#                                       S0101_C01_018M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                635
# 2                                                668
#
#                                       S0101_C01_019E  \
# 0  Estimate!!Total!!Total population!!AGE!!85 yea...
# 1                                               1391
# 2                                               3805
#
#                                       S0101_C01_019M  \
# 0  Margin of Error!!Total!!Total population!!AGE!...
# 1                                                594
# 2                                                879
#
#                                       S0101_C01_020E  \
# 0  Estimate!!Total!!Total population!!SELECTED AG...
# 1                                               8265
# 2                                              22346
#
#                                       S0101_C01_020M  \
# 0  Margin of Error!!Total!!Total population!!SELE...
# 1                                                774
# 2                                               1196
#
#                                       S0101_C01_021E  \
# 0  Estimate!!Total!!Total population!!SELECTED AG...
# 1                                               3157
# 2                                               7434
#
#                                       S0101_C01_021M  \
# 0  Margin of Error!!Total!!Total population!!SELE...
# 1                                                418
# 2                                                880
#
#                                       S0101_C01_022E  \
# 0  Estimate!!Total!!Total population!!SELECTED AG...
# 1                                              15274
# 2                                              41350
#
#                                       S0101_C01_022M  \
# 0  Margin of Error!!Total!!Total population!!SELE...
# 1                                              *****
# 2                                               1637
#
#                                       S0101_C01_023E  \
# 0  Estimate!!Total!!Total population!!SELECTED AG...
# 1                                               4855
# 2                                              21221
#
#                                       S0101_C01_023M  \
# 0  Margin of Error!!Total!!Total population!!SELE...
# 1                                                517
# 2                                               1222
#
#                                       S0101_C01_024E  \
# 0  Estimate!!Total!!Total population!!SELECTED AG...
# 1                                              24771
# 2                                              75856
#
#                                       S0101_C01_024M  ...  \
# 0  Margin of Error!!Total!!Total population!!SELE...  ...
# 1                                                916  ...
# 2                                               2253  ...
#
#                                       S0101_C06_014E  \
# 0  Estimate!!Percent Female!!Total population!!AG...
# 1                                                7.9
# 2                                                6.0
#
#                                       S0101_C06_014M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.9
# 2                                                1.0
#
#                                       S0101_C06_015E  \
# 0  Estimate!!Percent Female!!Total population!!AG...
# 1                                                6.7
# 2                                                5.8
#
#                                       S0101_C06_015M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.5
# 2                                                1.0
#
#                                       S0101_C06_016E  \
# 0  Estimate!!Percent Female!!Total population!!AG...
# 1                                                8.2
# 2                                                3.8
#
#                                       S0101_C06_016M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.7
# 2                                                0.8
#
#                                       S0101_C06_017E  \
# 0  Estimate!!Percent Female!!Total population!!AG...
# 1                                                3.9
# 2                                                3.2
#
#                                       S0101_C06_017M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.0
# 2                                                0.7
#
#                                       S0101_C06_018E  \
# 0  Estimate!!Percent Female!!Total population!!AG...
# 1                                                3.1
# 2                                                2.0
#
#                                       S0101_C06_018M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.2
# 2                                                0.6
#
#                                       S0101_C06_019E  \
# 0  Estimate!!Percent Female!!Total population!!AG...
# 1                                                2.1
# 2                                                2.8
#
#                                       S0101_C06_019M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.0
# 2                                                0.6
#
#                                       S0101_C06_020E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                                9.7
# 2                                               12.7
#
#                                       S0101_C06_020M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.1
# 2                                                0.9
#
#                                       S0101_C06_021E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                                5.8
# 2                                                4.5
#
#                                       S0101_C06_021M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.1
# 2                                                0.7
#
#                                       S0101_C06_022E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               21.5
# 2                                               23.9
#
#                                       S0101_C06_022M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.3
# 2                                                1.1
#
#                                       S0101_C06_023E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                                6.6
# 2                                               11.7
#
#                                       S0101_C06_023M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.0
# 2                                                0.8
#
#                                       S0101_C06_024E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               33.5
# 2                                               41.5
#
#                                       S0101_C06_024M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.9
# 2                                                1.2
#
#                                       S0101_C06_025E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               82.6
# 2                                               78.4
#
#                                       S0101_C06_025M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.6
# 2                                                1.4
#
#                                       S0101_C06_026E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               78.5
# 2                                               76.1
#
#                                       S0101_C06_026M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.3
# 2                                                1.1
#
#                                       S0101_C06_027E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               74.4
# 2                                               71.2
#
#                                       S0101_C06_027M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.7
# 2                                                1.8
#
#                                       S0101_C06_028E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               31.8
# 2                                               23.6
#
#                                       S0101_C06_028M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                2.0
# 2                                                1.2
#
#                                       S0101_C06_029E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               29.1
# 2                                               21.3
#
#                                       S0101_C06_029M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                1.6
# 2                                                1.2
#
#                                       S0101_C06_030E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                               24.0
# 2                                               17.6
#
#                                       S0101_C06_030M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                0.7
# 2                                                0.8
#
#                                       S0101_C06_031E  \
# 0  Estimate!!Percent Female!!Total population!!SE...
# 1                                                9.1
# 2                                                8.0
#
#                                       S0101_C06_031M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                0.6
# 2                                                0.8
#
#                                       S0101_C06_032E  \
# 0  Estimate!!Percent Female!!Total population!!SU...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_032M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_033E  \
# 0  Estimate!!Percent Female!!Total population!!SU...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_033M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_034E  \
# 0  Estimate!!Percent Female!!Total population!!SU...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_034M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_035E  \
# 0  Estimate!!Percent Female!!Total population!!SU...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_035M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_036E  \
# 0  Estimate!!Percent Female!!Total population!!SU...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_036M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_037E  \
# 0  Estimate!!Percent Female!!Total population!!PE...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_037M  \
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_038E  \
# 0  Estimate!!Percent Female!!Total population!!PE...
# 1                                                (X)
# 2                                                (X)
#
#                                       S0101_C06_038M
# 0  Margin of Error!!Percent Female!!Total populat...
# 1                                                (X)
# 2                                                (X)
#
# [3 rows x 458 columns]

# %%
#take out some unneeded characters from metro names
def clean_name(row):
    if 'Micro Area' in row:
        new_name = row.replace(' Micro Area', "")
    elif 'Metro Area' in row: 
        new_name = row.replace(' Metro Area', "")
    else: 
        new_name=row
    return new_name

# %%
#shift the rows so that row 1 becomes the column names and
#isn't included in the data itself
pd.options.display.max_columns=200
census_age.columns = census_age.iloc[0]
census_age = census_age[1:]

census_age.head(3)
# Out:
# 0              id     Geographic Area Name Estimate!!Total!!Total population  \
# 1  310M500US10140  Aberdeen, WA Micro Area                             75061
# 2  310M500US10180   Abilene, TX Metro Area                            171795
# 3  310M500US10300    Adrian, MI Micro Area                             98451
#
# 0 Margin of Error!!Total!!Total population  \
# 1                                    *****
# 2                                     2878
# 3                                    *****
#
# 0 Estimate!!Total!!Total population!!AGE!!Under 5 years  \
# 1                                               3852
# 2                                              11570
# 3                                               5374
#
# 0 Margin of Error!!Total!!Total population!!AGE!!Under 5 years  \
# 1                                                669
# 2                                                484
# 3                                                347
#
# 0 Estimate!!Total!!Total population!!AGE!!5 to 9 years  \
# 1                                               3260
# 2                                               9896
# 3                                               5210
#
# 0 Margin of Error!!Total!!Total population!!AGE!!5 to 9 years  \
# 1                                                838
# 2                                               1458
# 3                                                820
#
# 0 Estimate!!Total!!Total population!!AGE!!10 to 14 years  \
# 1                                               5005
# 2                                              12450
# 3                                               6216
#
# 0 Margin of Error!!Total!!Total population!!AGE!!10 to 14 years  \
# 1                                                765
# 2                                               1361
# 3                                                725
#
# 0 Estimate!!Total!!Total population!!AGE!!15 to 19 years  \
# 1                                               4828
# 2                                              13195
# 3                                               6044
#
# 0 Margin of Error!!Total!!Total population!!AGE!!15 to 19 years  \
# 1                                                687
# 2                                               1456
# 3                                                362
#
# 0 Estimate!!Total!!Total population!!AGE!!20 to 24 years  \
# 1                                               3184
# 2                                              15460
# 3                                               6519
#
# 0 Margin of Error!!Total!!Total population!!AGE!!20 to 24 years  \
# 1                                                629
# 2                                               1469
# 3                                                702
#
# 0 Estimate!!Total!!Total population!!AGE!!25 to 29 years  \
# 1                                               4062
# 2                                              12915
# 3                                               5415
#
# 0 Margin of Error!!Total!!Total population!!AGE!!25 to 29 years  \
# 1                                                406
# 2                                               1181
# 3                                                314
#
# 0 Estimate!!Total!!Total population!!AGE!!30 to 34 years  \
# 1                                               4529
# 2                                              11620
# 3                                               5464
#
# 0 Margin of Error!!Total!!Total population!!AGE!!30 to 34 years  \
# 1                                                699
# 2                                                709
# 3                                                458
#
# 0 Estimate!!Total!!Total population!!AGE!!35 to 39 years  \
# 1                                               3376
# 2                                              11087
# 3                                               6610
#
# 0 Margin of Error!!Total!!Total population!!AGE!!35 to 39 years  \
# 1                                                776
# 2                                               1706
# 3                                                859
#
# 0 Estimate!!Total!!Total population!!AGE!!40 to 44 years  \
# 1                                               4792
# 2                                              11579
# 3                                               5574
#
# 0 Margin of Error!!Total!!Total population!!AGE!!40 to 44 years  \
# 1                                                885
# 2                                               1883
# 3                                                951
#
# 0 Estimate!!Total!!Total population!!AGE!!45 to 49 years  \
# 1                                               4867
# 2                                               7663
# 3                                               6258
#
# 0 Margin of Error!!Total!!Total population!!AGE!!45 to 49 years  \
# 1                                                577
# 2                                                895
# 3                                                447
#
# 0 Estimate!!Total!!Total population!!AGE!!50 to 54 years  \
# 1                                               4862
# 2                                               8459
# 3                                               6191
#
# 0 Margin of Error!!Total!!Total population!!AGE!!50 to 54 years  \
# 1                                                591
# 2                                                910
# 3                                                255
#
# 0 Estimate!!Total!!Total population!!AGE!!55 to 59 years  \
# 1                                               5830
# 2                                              10242
# 3                                               7271
#
# 0 Margin of Error!!Total!!Total population!!AGE!!55 to 59 years  \
# 1                                               1058
# 2                                               1277
# 3                                                895
#
# 0 Estimate!!Total!!Total population!!AGE!!60 to 64 years  \
# 1                                               5754
# 2                                               9308
# 3                                               7014
#
# 0 Margin of Error!!Total!!Total population!!AGE!!60 to 64 years  \
# 1                                               1084
# 2                                               1089
# 3                                                819
#
# 0 Estimate!!Total!!Total population!!AGE!!65 to 69 years  \
# 1                                               4959
# 2                                               9118
# 3                                               6131
#
# 0 Margin of Error!!Total!!Total population!!AGE!!65 to 69 years  \
# 1                                                969
# 2                                               1266
# 3                                                703
#
# 0 Estimate!!Total!!Total population!!AGE!!70 to 74 years  \
# 1                                               5643
# 2                                               5563
# 3                                               5436
#
# 0 Margin of Error!!Total!!Total population!!AGE!!70 to 74 years  \
# 1                                               1003
# 2                                               1086
# 3                                                813
#
# 0 Estimate!!Total!!Total population!!AGE!!75 to 79 years  \
# 1                                               2950
# 2                                               4935
# 3                                               4046
#
# 0 Margin of Error!!Total!!Total population!!AGE!!75 to 79 years  \
# 1                                                553
# 2                                                817
# 3                                                644
#
# 0 Estimate!!Total!!Total population!!AGE!!80 to 84 years  \
# 1                                               1917
# 2                                               2930
# 3                                               2071
#
# 0 Margin of Error!!Total!!Total population!!AGE!!80 to 84 years  \
# 1                                                635
# 2                                                668
# 3                                                541
#
# 0 Estimate!!Total!!Total population!!AGE!!85 years and over  \
# 1                                               1391
# 2                                               3805
# 3                                               1607
#
# 0 Margin of Error!!Total!!Total population!!AGE!!85 years and over  \
# 1                                                594
# 2                                                879
# 3                                                467
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years  \
# 1                                               8265
# 2                                              22346
# 3                                              11426
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years  \
# 1                                                774
# 2                                               1196
# 3                                                290
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years  \
# 1                                               3157
# 2                                               7434
# 3                                               3722
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years  \
# 1                                                418
# 2                                                880
# 3                                                314
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years  \
# 1                                              15274
# 2                                              41350
# 3                                              20522
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years  \
# 1                                              *****
# 2                                               1637
# 3                                                181
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years  \
# 1                                               4855
# 2                                              21221
# 3                                               8841
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years  \
# 1                                                517
# 2                                               1222
# 3                                                660
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years  \
# 1                                              24771
# 2                                              75856
# 3                                              35626
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years  \
# 1                                                916
# 2                                               2253
# 3                                                641
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!16 years and over  \
# 1                                              61725
# 2                                             134883
# 3                                              80215
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!16 years and over  \
# 1                                                462
# 2                                               2275
# 3                                                490
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 years and over  \
# 1                                              59787
# 2                                             130445
# 3                                              77929
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 years and over  \
# 1                                              *****
# 2                                               2108
# 3                                                181
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!21 years and over  \
# 1                                              57334
# 2                                             121707
# 3                                              73986
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!21 years and over  \
# 1                                                734
# 2                                               2607
# 3                                                578
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!60 years and over  \
# 1                                              22614
# 2                                              35659
# 3                                              26305
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!60 years and over  \
# 1                                               1062
# 2                                               1726
# 3                                               1012
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!62 years and over  \
# 1                                              20596
# 2                                              31542
# 3                                              23723
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!62 years and over  \
# 1                                                993
# 2                                               1755
# 3                                               1024
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!65 years and over  \
# 1                                              16860
# 2                                              26351
# 3                                              19291
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!65 years and over  \
# 1                                                473
# 2                                               1308
# 3                                                585
#
# 0 Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!75 years and over  \
# 1                                               6258
# 2                                              11670
# 3                                               7724
#
# 0 Margin of Error!!Total!!Total population!!SELECTED AGE CATEGORIES!!75 years and over  \
# 1                                                261
# 2                                               1125
# 3                                                236
#
# 0 Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Median age (years)  \
# 1                                               45.5
# 2                                               34.6
# 3                                               42.1
#
# 0 Margin of Error!!Total!!Total population!!SUMMARY INDICATORS!!Median age (years)  \
# 1                                                0.7
# 2                                                0.5
# 3                                                0.9
#
# 0 Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 1                                              101.9
# 2                                              102.0
# 3                                              102.1
#
# 0 Margin of Error!!Total!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 1                                                4.6
# 2                                                3.6
# 3                                                2.2
#
# 0 Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 1                                               74.9
# 2                                               65.0
# 3                                               67.9
#
# 0 Margin of Error!!Total!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 1                                                1.9
# 2                                                2.3
# 3                                                1.5
#
# 0 Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 1                                               39.3
# 2                                               25.3
# 3                                               32.9
#
# 0 Margin of Error!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 1                                                1.5
# 2                                                1.5
# 3                                                1.3
#
# 0 Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 1                                               35.6
# 2                                               39.7
# 3                                               35.0
#
# 0 Margin of Error!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 1                                                0.4
# 2                                                1.6
# 3                                                0.4
#
# 0 Estimate!!Total!!Total population!!PERCENT ALLOCATED!!Sex  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Total!!Total population!!PERCENT ALLOCATED!!Sex  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Total!!Total population!!PERCENT ALLOCATED!!Age  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Total!!Total population!!PERCENT ALLOCATED!!Age  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent!!Total population  \
# 1                                 (X)
# 2                                 (X)
# 3                                 (X)
#
# 0 Margin of Error!!Percent!!Total population  \
# 1                                        (X)
# 2                                        (X)
# 3                                        (X)
#
# 0 Estimate!!Percent!!Total population!!AGE!!Under 5 years  \
# 1                                                5.1
# 2                                                6.7
# 3                                                5.5
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!Under 5 years  \
# 1                                                0.9
# 2                                                0.3
# 3                                                0.4
#
# 0 Estimate!!Percent!!Total population!!AGE!!5 to 9 years  \
# 1                                                4.3
# 2                                                5.8
# 3                                                5.3
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!5 to 9 years  \
# 1                                                1.1
# 2                                                0.8
# 3                                                0.8
#
# 0 Estimate!!Percent!!Total population!!AGE!!10 to 14 years  \
# 1                                                6.7
# 2                                                7.2
# 3                                                6.3
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!10 to 14 years  \
# 1                                                1.0
# 2                                                0.8
# 3                                                0.7
#
# 0 Estimate!!Percent!!Total population!!AGE!!15 to 19 years  \
# 1                                                6.4
# 2                                                7.7
# 3                                                6.1
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!15 to 19 years  \
# 1                                                0.9
# 2                                                0.8
# 3                                                0.4
#
# 0 Estimate!!Percent!!Total population!!AGE!!20 to 24 years  \
# 1                                                4.2
# 2                                                9.0
# 3                                                6.6
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!20 to 24 years  \
# 1                                                0.8
# 2                                                0.8
# 3                                                0.7
#
# 0 Estimate!!Percent!!Total population!!AGE!!25 to 29 years  \
# 1                                                5.4
# 2                                                7.5
# 3                                                5.5
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!25 to 29 years  \
# 1                                                0.5
# 2                                                0.7
# 3                                                0.3
#
# 0 Estimate!!Percent!!Total population!!AGE!!30 to 34 years  \
# 1                                                6.0
# 2                                                6.8
# 3                                                5.5
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!30 to 34 years  \
# 1                                                0.9
# 2                                                0.4
# 3                                                0.5
#
# 0 Estimate!!Percent!!Total population!!AGE!!35 to 39 years  \
# 1                                                4.5
# 2                                                6.5
# 3                                                6.7
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!35 to 39 years  \
# 1                                                1.0
# 2                                                1.0
# 3                                                0.9
#
# 0 Estimate!!Percent!!Total population!!AGE!!40 to 44 years  \
# 1                                                6.4
# 2                                                6.7
# 3                                                5.7
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!40 to 44 years  \
# 1                                                1.2
# 2                                                1.1
# 3                                                1.0
#
# 0 Estimate!!Percent!!Total population!!AGE!!45 to 49 years  \
# 1                                                6.5
# 2                                                4.5
# 3                                                6.4
#
# 0 Margin of Error!!Percent!!Total population!!AGE!!45 to 49 years  ...  \
# 1                                                0.8               ...
# 2                                                0.5               ...
# 3                                                0.5               ...
#
# 0 Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over  \
# 1                                              27666
# 2                                              60557
# 3                                              36820
#
# 0 Margin of Error!!Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over  \
# 1                                                539
# 2                                               1687
# 3                                                531
#
# 0 Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over  \
# 1                                              11839
# 2                                              20069
# 3                                              14017
#
# 0 Margin of Error!!Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over  \
# 1                                                699
# 2                                               1063
# 3                                                607
#
# 0 Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over  \
# 1                                              10804
# 2                                              18092
# 3                                              12888
#
# 0 Margin of Error!!Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over  \
# 1                                                562
# 2                                               1012
# 3                                                628
#
# 0 Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over  \
# 1                                               8908
# 2                                              14964
# 3                                              10468
#
# 0 Margin of Error!!Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over  \
# 1                                                298
# 2                                                686
# 3                                                407
#
# 0 Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over  \
# 1                                               3375
# 2                                               6787
# 3                                               4419
#
# 0 Margin of Error!!Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over  \
# 1                                                222
# 2                                                672
# 3                                                144
#
# 0 Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Median age (years)  \
# 1                                               45.4
# 2                                               36.1
# 3                                               43.4
#
# 0 Margin of Error!!Female!!Total population!!SUMMARY INDICATORS!!Median age (years)  \
# 1                                                0.6
# 2                                                1.4
# 3                                                0.9
#
# 0 Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent Female!!Total population  \
# 1                                        (X)
# 2                                        (X)
# 3                                        (X)
#
# 0 Margin of Error!!Percent Female!!Total population  \
# 1                                               (X)
# 2                                               (X)
# 3                                               (X)
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!Under 5 years  \
# 1                                                6.0
# 2                                                6.7
# 3                                                5.5
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!Under 5 years  \
# 1                                                1.6
# 2                                                0.7
# 3                                                0.5
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!5 to 9 years  \
# 1                                                4.1
# 2                                                5.5
# 3                                                5.4
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!5 to 9 years  \
# 1                                                1.7
# 2                                                1.3
# 3                                                1.2
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!10 to 14 years  \
# 1                                                5.7
# 2                                                7.2
# 3                                                6.7
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!10 to 14 years  \
# 1                                                1.7
# 2                                                1.0
# 3                                                1.2
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!15 to 19 years  \
# 1                                                9.5
# 2                                                8.1
# 3                                                5.5
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!15 to 19 years  \
# 1                                                1.6
# 2                                                1.5
# 3                                                0.3
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!20 to 24 years  \
# 1                                                2.8
# 2                                                8.2
# 3                                                6.2
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!20 to 24 years  \
# 1                                                1.4
# 2                                                1.3
# 3                                                1.0
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!25 to 29 years  \
# 1                                                5.0
# 2                                                7.0
# 3                                                5.7
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!25 to 29 years  \
# 1                                                0.8
# 2                                                0.8
# 3                                                0.6
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!30 to 34 years  \
# 1                                                5.3
# 2                                                6.3
# 3                                                4.9
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!30 to 34 years  \
# 1                                                0.9
# 2                                                0.6
# 3                                                0.4
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!35 to 39 years  \
# 1                                                4.3
# 2                                                6.2
# 3                                                6.8
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!35 to 39 years  \
# 1                                                1.5
# 2                                                1.1
# 3                                                1.4
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!40 to 44 years  \
# 1                                                6.6
# 2                                                5.9
# 3                                                5.1
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!40 to 44 years  \
# 1                                                1.7
# 2                                                1.2
# 3                                                1.4
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!45 to 49 years  \
# 1                                                6.2
# 2                                                4.4
# 3                                                6.2
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!45 to 49 years  \
# 1                                                1.0
# 2                                                0.8
# 3                                                0.5
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!50 to 54 years  \
# 1                                                5.4
# 2                                                5.0
# 3                                                6.1
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!50 to 54 years  \
# 1                                                0.4
# 2                                                0.7
# 3                                                0.3
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!55 to 59 years  \
# 1                                                7.3
# 2                                                6.1
# 3                                                7.1
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!55 to 59 years  \
# 1                                                2.0
# 2                                                1.2
# 3                                                1.1
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!60 to 64 years  \
# 1                                                7.9
# 2                                                6.0
# 3                                                7.3
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!60 to 64 years  \
# 1                                                1.9
# 2                                                1.0
# 3                                                0.9
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!65 to 69 years  \
# 1                                                6.7
# 2                                                5.8
# 3                                                6.4
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!65 to 69 years  \
# 1                                                1.5
# 2                                                1.0
# 3                                                1.1
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!70 to 74 years  \
# 1                                                8.2
# 2                                                3.8
# 3                                                6.0
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!70 to 74 years  \
# 1                                                1.7
# 2                                                0.8
# 3                                                1.1
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!75 to 79 years  \
# 1                                                3.9
# 2                                                3.2
# 3                                                4.2
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!75 to 79 years  \
# 1                                                1.0
# 2                                                0.7
# 3                                                0.9
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!80 to 84 years  \
# 1                                                3.1
# 2                                                2.0
# 3                                                2.8
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!80 to 84 years  \
# 1                                                1.2
# 2                                                0.6
# 3                                                0.7
#
# 0 Estimate!!Percent Female!!Total population!!AGE!!85 years and over  \
# 1                                                2.1
# 2                                                2.8
# 3                                                2.1
#
# 0 Margin of Error!!Percent Female!!Total population!!AGE!!85 years and over  \
# 1                                                1.0
# 2                                                0.6
# 3                                                0.6
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years  \
# 1                                                9.7
# 2                                               12.7
# 3                                               12.1
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years  \
# 1                                                1.1
# 2                                                0.9
# 3                                                0.7
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years  \
# 1                                                5.8
# 2                                                4.5
# 3                                                3.3
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years  \
# 1                                                1.1
# 2                                                0.7
# 3                                                0.3
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years  \
# 1                                               21.5
# 2                                               23.9
# 3                                               21.0
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years  \
# 1                                                1.3
# 2                                                1.1
# 3                                                0.6
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years  \
# 1                                                6.6
# 2                                               11.7
# 3                                                8.4
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years  \
# 1                                                1.0
# 2                                                0.8
# 3                                                1.0
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years  \
# 1                                               33.5
# 2                                               41.5
# 3                                               34.2
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years  \
# 1                                                1.9
# 2                                                1.2
# 3                                                0.9
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over  \
# 1                                               82.6
# 2                                               78.4
# 3                                               80.5
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over  \
# 1                                                1.6
# 2                                                1.4
# 3                                                0.8
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over  \
# 1                                               78.5
# 2                                               76.1
# 3                                               79.0
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over  \
# 1                                                1.3
# 2                                                1.1
# 3                                                0.6
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over  \
# 1                                               74.4
# 2                                               71.2
# 3                                               75.6
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over  \
# 1                                                1.7
# 2                                                1.8
# 3                                                0.8
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over  \
# 1                                               31.8
# 2                                               23.6
# 3                                               28.8
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over  \
# 1                                                2.0
# 2                                                1.2
# 3                                                1.2
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over  \
# 1                                               29.1
# 2                                               21.3
# 3                                               26.5
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over  \
# 1                                                1.6
# 2                                                1.2
# 3                                                1.2
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over  \
# 1                                               24.0
# 2                                               17.6
# 3                                               21.5
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over  \
# 1                                                0.7
# 2                                                0.8
# 3                                                0.8
#
# 0 Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over  \
# 1                                                9.1
# 2                                                8.0
# 3                                                9.1
#
# 0 Margin of Error!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over  \
# 1                                                0.6
# 2                                                0.8
# 3                                                0.3
#
# 0 Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Median age (years)  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Median age (years)  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Sex  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Estimate!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age  \
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# 0 Margin of Error!!Percent Female!!Total population!!PERCENT ALLOCATED!!Age
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
#
# [3 rows x 458 columns]

# %%
census_age['clean_name'] = census_age['Geographic Area Name'].apply(clean_name)

# %%
census_age = census_age[['id', 'clean_name', 'Estimate!!Total!!Total population', 
                        'Estimate!!Total!!Total population!!AGE!!15 to 19 years', 'Estimate!!Total!!Total population!!AGE!!20 to 24 years',
                       'Estimate!!Total!!Total population!!AGE!!25 to 29 years','Estimate!!Total!!Total population!!AGE!!30 to 34 years']]

# %%
#clean up the names to make reading the data easier
census_age.rename({'Estimate!!Total!!Total population':'total_pop_estimate', 
                   'Estimate!!Total!!Total population!!AGE!!15 to 19 years':'15_to_19',
                  'Estimate!!Total!!Total population!!AGE!!20 to 24 years':'20_to_24', 
                   'Estimate!!Total!!Total population!!AGE!!25 to 29 years':'25_to_29', 
                  'Estimate!!Total!!Total population!!AGE!!30 to 34 years':'30_to_34'}, axis=1, inplace=True)
census_age.head()
# Out:
# 0              id             clean_name total_pop_estimate 15_to_19 20_to_24  \
# 1  310M500US10140           Aberdeen, WA              75061     4828     3184
# 2  310M500US10180            Abilene, TX             171795    13195    15460
# 3  310M500US10300             Adrian, MI              98451     6044     6519
# 4  310M500US10380  Aguadilla-Isabela, PR             288877    17627    21061
# 5  310M500US10420              Akron, OH             703479    45160    52153
#
# 0 25_to_29 30_to_34
# 1     4062     4529
# 2    12915    11620
# 3     5415     5464
# 4    15736    17630
# 5    47606    43989

# %%
#change strings to ints
for col in ['total_pop_estimate','15_to_19','20_to_24','25_to_29','30_to_34']:
    census_age[col] = census_age[col].astype(int)

# %%
#get the percentage of the population that is in each age group
def get_pop_percentage(pop_estimate, subgroup):
    percentage = subgroup/pop_estimate
    return percentage*100

for col in ['15_to_19', '20_to_24', '25_to_29', '30_to_34']:
    census_age[f'{col}_percentage'] = census_age.apply(lambda x: get_pop_percentage(x.total_pop_estimate, x[col]), axis=1)

# %%
#add together 'young' age groups and get that proportion of the population
census_age['total_young_pop'] = census_age['15_to_19'] + census_age['20_to_24']+census_age['25_to_29']+census_age['30_to_34']
census_age['young_pop_percent'] = (census_age.total_young_pop / census_age.total_pop_estimate) *100

# %%
census_age.head(3)
# Out:
# 0              id    clean_name  total_pop_estimate  15_to_19  20_to_24  \
# 1  310M500US10140  Aberdeen, WA               75061      4828      3184
# 2  310M500US10180   Abilene, TX              171795     13195     15460
# 3  310M500US10300    Adrian, MI               98451      6044      6519
#
# 0  25_to_29  30_to_34  15_to_19_percentage  20_to_24_percentage  \
# 1      4062      4529             6.432102             4.241883
# 2     12915     11620             7.680666             8.999098
# 3      5415      5464             6.139095             6.621568
#
# 0  25_to_29_percentage  30_to_34_percentage  total_young_pop  \
# 1             5.411599             6.033759            16603
# 2             7.517681             6.763876            53190
# 3             5.500198             5.549969            23442
#
# 0  young_pop_percent
# 1          22.119343
# 2          30.961320
# 3          23.810830

# %%
census_age = census_age[census_age.total_young_pop<88000000]

# %%
#save cleaned data to csv
census_age.to_csv('Cleaned_Census_Data.csv')

# %% [markdown]
# ## College Data

# %% [markdown]
# Another area we could potentially target is colleges & universities, which are full of young people who often need to travel home. Below we clean data on US colleges & universities for mapping. In the end, it will include info on the school, its lat/long, tuition data, and numbers of out of state students that could be relevant advertising targets.

# %%
school_df = pd.read_csv('Base_Ed_Spreadsheet.csv')

# %%
pd.options.display.max_columns=100
school_df.drop(labels=['number_enrolled_pt', 'open_admissions_policy', 'inst_control', 'institution_level',
                      'inst_category'], axis=1, inplace=True)
school_df.head(3)
# Out:
#    year  unitid                            inst_name state_name  \
# 0  2018  100654             Alabama A & M University    Alabama
# 1  2018  100663  University of Alabama at Birmingham    Alabama
# 2  2018  100690                   Amridge University    Alabama
#
#    number_enrolled_ft hbcu tribal_college     date_closed inst_status  \
# 0              1525.0  Yes             No  Not applicable      Active
# 1              2245.0   No             No  Not applicable      Active
# 2                 NaN   No             No  Not applicable      Active
#
#   open_public             postsec_public_active         inst_size  \
# 0         Yes  Active postsecondary institution       5,000-9,999
# 1         Yes  Active postsecondary institution  20,000 and above
# 2         Yes  Active postsecondary institution       Under 1,000
#
#                                    cc_undergrad_2018  \
# 0  Four-year, nearly all full-time, inclusive acc...
# 1  Four-year, mostly full-time, selective accepta...
# 2                        Four-year, mostly part-time
#
#                               cc_size_setting_2018 dist_progs_all  \
# 0            Four-year, medium, highly residential             No
# 1       Four-year, large, primarily nonresidential             No
# 2  Four-year, very small, primarily nonresidential            Yes
#
#   calendar_system
# 0        Semester
# 1        Semester
# 2        Semester

# %%
#filter any schools out that aren't residential or that are very small
school_df = school_df[~school_df.cc_undergrad_2018.str.contains('mostly part-time')&
                     ~school_df.cc_undergrad_2018.str.contains('Not classified')&
                     ~school_df.cc_undergrad_2018.str.contains('mixed part/full-time')&
                     ~school_df.cc_undergrad_2018.str.contains('not accredited')&
                     ~school_df.cc_size_setting_2018.str.contains('primarily nonresidential')&
                     ~school_df.cc_size_setting_2018.str.contains('very small')]

#only include schools that are in the states we're targeting based on airline data
school_df = school_df[(school_df.state_name == 'Pennsylvania') |(school_df.state_name == 'Massachusetts')| (school_df.state_name == 'New York')|
                     (school_df.state_name == 'District of Columbia')| (school_df.state_name=='California')| (school_df.state_name=='North Carolina')|
                     (school_df.state_name=='Colorado')|(school_df.state_name=='Utah')|(school_df.state_name=='Oregon')|(school_df.state_name=='Illinois')|
                     (school_df.state_name=='Florida')|(school_df.state_name=='Washington') | (school_df.state_name=='New Jersey')]

#must be active schools
school_df = school_df[school_df.postsec_public_active == "Active postsecondary institution"]

#can't be only distance education schools
school_df = school_df[school_df.dist_progs_all == "No"]

# %%
school_df.drop(labels=['year', 'date_closed', 'inst_status', 'open_public', 'postsec_public_active', 
                      'dist_progs_all', 'calendar_system'], axis=1, inplace=True)
school_df.shape
# Out:
# (462, 9)

# %%
#get the tuition fees for each school 
tuition = pd.read_csv('School_Tuition_Breakdown.csv')

# %%
tuition = tuition[(tuition.level_of_study == 'Undergraduate') & (tuition.tuition_type!='In district')]
tuition.sort_values(by=['unitid', 'tuition_type'], inplace=True)

# %%
tuition.head(5)
# Out:
#     year  unitid                            inst_name state_name  \
# 1   2018  100654             Alabama A & M University    Alabama
# 2   2018  100654             Alabama A & M University    Alabama
# 7   2018  100663  University of Alabama at Birmingham    Alabama
# 8   2018  100663  University of Alabama at Birmingham    Alabama
# 13  2018  100690                   Amridge University    Alabama
#
#    level_of_study  tuition_type  tuition_fees_ft
# 1   Undergraduate      In state           9744.0
# 2   Undergraduate  Out of state          18354.0
# 7   Undergraduate      In state           8568.0
# 8   Undergraduate  Out of state          19704.0
# 13  Undergraduate      In state           9900.0

# %%
tuition.dropna(inplace=True)
#find the difference between each school's instate and out of state tuition
diffs = np.diff(tuition.tuition_fees_ft)

# %%
#insert nan at the beginning of the diffs array to realign it
diffs2 = np.insert(diffs, 0, np.nan)
diffs2
# Out:
# array([   nan,  8610., -9786., ...,     0., -5604.,     0.])

# %%
#add in the diffs array as a column
tuition['outofstate-instate'] = diffs2

# %%
#filter out the in state rows
tuition = tuition[tuition.tuition_type=="Out of state"]

# %%
tuition.head(3)
# Out:
#     year  unitid                            inst_name state_name  \
# 2   2018  100654             Alabama A & M University    Alabama
# 8   2018  100663  University of Alabama at Birmingham    Alabama
# 14  2018  100690                   Amridge University    Alabama
#
#    level_of_study  tuition_type  tuition_fees_ft  outofstate-instate
# 2   Undergraduate  Out of state          18354.0              8610.0
# 8   Undergraduate  Out of state          19704.0             11136.0
# 14  Undergraduate  Out of state           9900.0                 0.0

# %%
#merge college and tuition datasets
school_tuition = school_df.merge(tuition, on='unitid', how='left')

# %%
school_tuition.head(3)
# Out:
#    unitid                    inst_name_x state_name_x  number_enrolled_ft  \
# 0  109785       Azusa Pacific University   California              1107.0
# 1  110097               Biola University   California               857.0
# 2  110361  California Baptist University   California              1570.0
#
#   hbcu tribal_college      inst_size  \
# 0   No             No  10,000-19,999
# 1   No             No    5,000-9,999
# 2   No             No  10,000-19,999
#
#                                    cc_undergrad_2018  \
# 0  Four-year, nearly all full-time, selective acc...
# 1  Four-year, nearly all full-time, selective acc...
# 2  Four-year, nearly all full-time, selective acc...
#
#                        cc_size_setting_2018    year  \
# 0     Four-year, medium, highly residential  2018.0
# 1     Four-year, medium, highly residential  2018.0
# 2  Four-year, medium, primarily residential  2018.0
#
#                      inst_name_y state_name_y level_of_study  tuition_type  \
# 0       Azusa Pacific University   California  Undergraduate  Out of state
# 1               Biola University   California  Undergraduate  Out of state
# 2  California Baptist University   California  Undergraduate  Out of state
#
#    tuition_fees_ft  outofstate-instate
# 0          38880.0                 0.0
# 1          40488.0                 0.0
# 2          33478.0                 0.0

# %%
#this dataset contains the lat/long data for the schools
geographies = pd.read_excel('School_Geographies.xlsx')

# %%
#if the school ID is in our school_tuition dataset, include it
geographies= geographies[geographies.UNITID.isin(school_tuition.unitid.unique())]

# %%
geographies.drop(labels=['STREET', 'STFIP', 'CNTY', 'NMCNTY', 'LOCALE', 'CBSATYPE', 'CSA', 'NMCSA', 'NECTA', 'NMNECTA',
                        'CD', 'SLDL', 'SLDU', 'SCHOOLYEAR'], axis=1, inplace=True)

# %%
geographies.rename({'UNITID':'unitid'}, axis=1, inplace=True)
geographies.head(3)
# Out:
#      unitid                           NAME       CITY STATE         ZIP  \
# 213  109785       Azusa Pacific University      Azusa    CA  91702-7000
# 218  110097               Biola University  La Mirada    CA  90639-0001
# 224  110361  California Baptist University  Riverside    CA  92504-3297
#
#            LAT         LON   CBSA                                NMCBSA
# 213  34.130047 -117.888375  31080    Los Angeles-Long Beach-Anaheim, CA
# 218  33.906203 -118.014374  31080    Los Angeles-Long Beach-Anaheim, CA
# 224  33.929321 -117.425619  40140  Riverside-San Bernardino-Ontario, CA

# %%
#merge school & tuition dataset with the latitude and longitude
school_tuition_latlong = school_tuition.merge(geographies, on='unitid', how='left')

# %%
school_tuition_latlong.head(3)
# Out:
#    unitid                    inst_name_x state_name_x  number_enrolled_ft  \
# 0  109785       Azusa Pacific University   California              1107.0
# 1  110097               Biola University   California               857.0
# 2  110361  California Baptist University   California              1570.0
#
#   hbcu tribal_college      inst_size  \
# 0   No             No  10,000-19,999
# 1   No             No    5,000-9,999
# 2   No             No  10,000-19,999
#
#                                    cc_undergrad_2018  \
# 0  Four-year, nearly all full-time, selective acc...
# 1  Four-year, nearly all full-time, selective acc...
# 2  Four-year, nearly all full-time, selective acc...
#
#                        cc_size_setting_2018    year  \
# 0     Four-year, medium, highly residential  2018.0
# 1     Four-year, medium, highly residential  2018.0
# 2  Four-year, medium, primarily residential  2018.0
#
#                      inst_name_y state_name_y level_of_study  tuition_type  \
# 0       Azusa Pacific University   California  Undergraduate  Out of state
# 1               Biola University   California  Undergraduate  Out of state
# 2  California Baptist University   California  Undergraduate  Out of state
#
#    tuition_fees_ft  outofstate-instate                           NAME  \
# 0          38880.0                 0.0       Azusa Pacific University
# 1          40488.0                 0.0               Biola University
# 2          33478.0                 0.0  California Baptist University
#
#         CITY STATE         ZIP        LAT         LON   CBSA  \
# 0      Azusa    CA  91702-7000  34.130047 -117.888375  31080
# 1  La Mirada    CA  90639-0001  33.906203 -118.014374  31080
# 2  Riverside    CA  92504-3297  33.929321 -117.425619  40140
#
#                                  NMCBSA
# 0    Los Angeles-Long Beach-Anaheim, CA
# 1    Los Angeles-Long Beach-Anaheim, CA
# 2  Riverside-San Bernardino-Ontario, CA

# %%
#clean up a few inconsistent metro area names
def clean_CBSA(row):
    if row == "Raleigh-Cary, NC":
        return "Raleigh, NC"
    elif row == "Sacramento-Roseville-Folsom, CA":
        return "Sacramento--Roseville--Arden-Arcade, CA"
    else:
        return row
    
school_tuition_latlong['NMCBSA'] = school_tuition_latlong['NMCBSA'].apply(clean_CBSA)

# %%
#this dataset contains info on how many freshmen students were
#from out of state
out_of_staters = pd.read_csv('Out_of_Staters.csv')

#only include rows that include schools in our geographies as well
#as students who are from the state at the other end of the Amtrak route
def pick_rows(state_name, res_state):
    if state_name == "Massachusetts":
        if res_state in ["Pennsylvania", 'New Jersey', 'District of Columbia']:
            return 1
    elif state_name == "California":
        if res_state in ["California", "Oregon"]:
            return 1
    elif state_name == "New York":
        if res_state in ["North Carolina"]:
            return 1
    elif state_name == "Colorado":
        if res_state in ["Utah", "Illinois"]:
            return 1
    elif state_name == "Oregon":
        if res_state in ["California"]:
            return 1
    elif state_name == "Pennsylvania":
        if res_state in ["Massachusetts"]:
            return 1
    elif state_name == "New Jersey":
        if res_state in ["Massachusetts"]:
            return 1
    elif state_name == "District of Columbia":
        if res_state in ["Massachusetts"]:
            return 1
    elif state_name == "North Carolina":
        if res_state in ["New York"]:
            return 1
    elif state_name == "Utah":
        if res_state in ["Colorado"]:
            return 1
    elif state_name =="Illinois":
        if res_state in ["Colorado"]:
            return 1
        
        
out_of_staters['include'] = out_of_staters.apply(lambda x: pick_rows(x.state_name, x.state_of_residence), axis=1)

# %%
out_of_staters = out_of_staters[out_of_staters.include==1]

# %%
out_of_staters.head(3)
# Out:
#       year  unitid                  inst_name  state_name state_of_residence  \
# 3335  2018  108232  Academy of Art University  California         California
# 3338  2018  108232  Academy of Art University  California             Oregon
# 3347  2018  108232  Academy of Art University  California             Oregon
#
#                          type_of_freshman  enrollment_fall  include
# 3335                                Total            203.0      1.0
# 3338                                Total              7.0      1.0
# 3347  Graduated from HS in past 12 months              5.0      1.0

# %%
#merge the out of state data into our dataset
merged_schools_freshmen = school_tuition_latlong.merge(out_of_staters, on="unitid", how="left")

# %%
merged_schools_freshmen.head(3)
# Out:
#    unitid               inst_name_x state_name_x  number_enrolled_ft hbcu  \
# 0  109785  Azusa Pacific University   California              1107.0   No
# 1  109785  Azusa Pacific University   California              1107.0   No
# 2  109785  Azusa Pacific University   California              1107.0   No
#
#   tribal_college      inst_size  \
# 0             No  10,000-19,999
# 1             No  10,000-19,999
# 2             No  10,000-19,999
#
#                                    cc_undergrad_2018  \
# 0  Four-year, nearly all full-time, selective acc...
# 1  Four-year, nearly all full-time, selective acc...
# 2  Four-year, nearly all full-time, selective acc...
#
#                     cc_size_setting_2018  year_x               inst_name_y  \
# 0  Four-year, medium, highly residential  2018.0  Azusa Pacific University
# 1  Four-year, medium, highly residential  2018.0  Azusa Pacific University
# 2  Four-year, medium, highly residential  2018.0  Azusa Pacific University
#
#   state_name_y level_of_study  tuition_type  tuition_fees_ft  \
# 0   California  Undergraduate  Out of state          38880.0
# 1   California  Undergraduate  Out of state          38880.0
# 2   California  Undergraduate  Out of state          38880.0
#
#    outofstate-instate                      NAME   CITY STATE         ZIP  \
# 0                 0.0  Azusa Pacific University  Azusa    CA  91702-7000
# 1                 0.0  Azusa Pacific University  Azusa    CA  91702-7000
# 2                 0.0  Azusa Pacific University  Azusa    CA  91702-7000
#
#          LAT         LON   CBSA                              NMCBSA  year_y  \
# 0  34.130047 -117.888375  31080  Los Angeles-Long Beach-Anaheim, CA  2018.0
# 1  34.130047 -117.888375  31080  Los Angeles-Long Beach-Anaheim, CA  2018.0
# 2  34.130047 -117.888375  31080  Los Angeles-Long Beach-Anaheim, CA  2018.0
#
#                   inst_name  state_name state_of_residence  \
# 0  Azusa Pacific University  California         California
# 1  Azusa Pacific University  California         California
# 2  Azusa Pacific University  California             Oregon
#
#                       type_of_freshman  enrollment_fall  include
# 0                                Total            786.0      1.0
# 1  Graduated from HS in past 12 months            776.0      1.0
# 2                                Total             23.0      1.0

# %%
#filter down to only the geographies that are relevant in our Amtrak analysis
merged_schools_freshmen=merged_schools_freshmen[(merged_schools_freshmen.NMCBSA == "Boston-Cambridge-Newton, MA-NH")|
                                               (merged_schools_freshmen.NMCBSA == "Los Angeles-Long Beach-Anaheim, CA")|
                                               (merged_schools_freshmen.NMCBSA == "New York-Newark-Jersey City, NY-NJ-PA")|
                                               (merged_schools_freshmen.NMCBSA == "Denver-Aurora-Lakewood, CO")|
                                               (merged_schools_freshmen.NMCBSA == "Portland-Vancouver-Hillsboro, OR-WA")|
                                               (merged_schools_freshmen.NMCBSA == "Philadelphia-Camden-Wilmington, PA-NJ-DE-MD")|
                                               (merged_schools_freshmen.NMCBSA == "Washington-Arlington-Alexandria, DC-VA-MD-WV")|
                                               (merged_schools_freshmen.NMCBSA == "San Jose-Sunnyvale-Santa Clara, CA")|
                                               (merged_schools_freshmen.NMCBSA == "Raleigh, NC")|
                                               (merged_schools_freshmen.NMCBSA == "Sacramento--Roseville--Arden-Arcade, CA")|
                                               (merged_schools_freshmen.NMCBSA == "Salt Lake City, UT")|
                                               (merged_schools_freshmen.NMCBSA == "Chicago-Naperville-Elgin, IL-IN-WI")]

# %%
#save all of the cleaned data for a backup
school_tuition_latlong.to_csv('Schools_All_Info.csv')
out_of_staters.to_csv('out_of_staters_clean.csv')
merged_schools_freshmen.to_csv('merged_schools_and_makeup.csv')
